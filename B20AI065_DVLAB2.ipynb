# %% [markdown]
# <a href="https://colab.research.google.com/github/StutiAswani/DV-LAB/blob/main/B20AI065_DVLAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #Numeric

# %% [markdown]
# ##AIRBNB PRICES ON THE FRENCH RIVIERA

# %% [markdown]
# ###histogram

# %%
sns.set_theme()
sns.set_style("whitegrid")
sns.set_context("paper")

# %%
df=pd.read_csv("https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/1_OneNum.csv")
df=df[df['price']<300]
df
# Out:
#       price
# 0      75.0
# 1     104.0
# 4      92.0
# 5      64.0
# 6     265.0
# ...     ...
# 9990   97.0
# 9991   58.0
# 9992  127.0
# 9993  143.0
# 9994  132.0
#
# [8904 rows x 1 columns]

# %%
plt.title("Night price distribution of Airbnb appartments",fontsize=12)
plt.hist(df.price,bins=np.arange(0,300,10),color="#69b3a2",rwidth=0.9,zorder=3)
plt.grid(zorder=0)
plt.xlabel("price")
plt.xticks([0,100,200,300])
plt.yticks([0,250,500,750])
plt.show()

# %%
plt.title("Night price distribution of Airbnb appartments",fontsize=12)
plt.hist(df.price,bins=np.arange(0,300,2),color="#69b3a2",rwidth=0.8,zorder=3)
plt.grid(zorder=0)
plt.xlabel("price")
plt.xticks([0,100,200,300])
plt.yticks([0,200,400])
plt.show()

# %% [markdown]
# ###density

# %%
sns.kdeplot(df.price,shade=True,bw=0.16,color="#69b3a2")
plt.title("Bandwidth: 10",fontsize=12)
plt.xticks([0,100,200,300])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.16 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(df.price,shade=True,bw=0.04,color="#69b3a2")
plt.title("Bandwidth: 10",fontsize=12)
plt.xticks([0,100,200,300])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.04 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##APARTMENT PRICE VS GROUND LIVING AREA.

# %%
df=pd.read_csv("https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/2_TwoNum.csv")
df['SalePrice']=df['SalePrice'].apply(lambda x: x/1000)
df
# Out:
#       GrLivArea  SalePrice
# 0          1710    208.500
# 1          1262    181.500
# 2          1786    223.500
# 3          1717    140.000
# 4          2198    250.000
# ...         ...        ...
# 1455       1647    175.000
# 1456       2073    210.000
# 1457       2340    266.500
# 1458       1078    142.125
# 1459       1256    147.500
#
# [1460 rows x 2 columns]

# %% [markdown]
# ###distribution

# %%
plt.title("Ground Living Area Distribution",fontsize=12)
plt.hist(df.GrLivArea,bins=np.arange(0,5000,100),color="#69b3a2",rwidth=0.9,zorder=3)
plt.grid(zorder=0)
plt.xlabel("area")
plt.ylabel("count")
plt.xticks([0,1000,2000,3000,4000,5000])
plt.yticks([0,50,100])
plt.show()

# %%
plt.title("Sale Price Distribution",fontsize=12)
plt.hist(df.SalePrice,bins=np.arange(0,700,20),color="#69b3a2",rwidth=0.9,zorder=3)
plt.grid(zorder=0)
plt.xlabel("Sale price (k$)")
plt.ylabel("count")
plt.xticks([0,200,400,600])
plt.yticks([0,50,100,150])
plt.show()

# %% [markdown]
# ###scatterplot

# %%
df.plot.scatter(y = 'SalePrice', x = 'GrLivArea', color="#69b3a2")
plt.title("Ground living area partially explains sale price of apartments", size=12)
plt.xlabel('Ground living area')
plt.ylabel('Sale price (k$)')
plt.yticks([0,200,400,600])
plt.xticks([0,1000,2000,3000,4000,5000])
plt.show()

# %% [markdown]
# ###regression

# %%
df.plot.scatter(y = 'SalePrice', x = 'GrLivArea', color="#69b3a2")
sns.regplot(data=df, x='GrLivArea', y='SalePrice', color="black", ci=None, scatter=False)
plt.title("Ground living area partially explains sale price of apartments", size=12)
plt.xlabel('Ground living area')
plt.ylabel('Sale price (k$)')
plt.yticks([0,200,400,600])
plt.xticks([0,1000,2000,3000,4000,5000])
plt.show()

# %% [markdown]
# ###overplotting

# %%
df.plot.scatter(y = 'SalePrice', x = 'GrLivArea', color="#69b3a2",s=25)
plt.title("Dot Size", size=12)
plt.xlabel('Ground living area')
plt.ylabel('Sale price (k$)')
plt.yticks([0,200,400,600])
plt.xticks([0,1000,2000,3000,4000,5000])
plt.show()

# %%
sns.kdeplot(x=df.GrLivArea, y=df.SalePrice, color="#69b3a2")
plt.title("Density 2d: contour", size=12)
plt.xlabel('Ground living area')
plt.ylabel('Sale price (k$)')
plt.ylim(0,500)
plt.yticks([0,100,200,300])
plt.xticks([0,1000,2000])
plt.show()

# %%
sns.kdeplot(x=df.GrLivArea, y=df.SalePrice, color="#69b3a2", cmap="Blues_r",shade=True)
plt.title("Density 2d: area", size=12)
plt.xlabel('Ground living area')
plt.ylabel('Sale price (k$)')
plt.xlim(0,3000)
plt.ylim(0,500)
plt.yticks([0,100,200,300])
plt.xticks([0,1000,2000])
plt.show()

# %%
plt.hist2d(x=df.GrLivArea, y=df.SalePrice, bins=(50, 50), cmap="BuPu")
plt.title("2d histogram", size=12)
plt.xlabel('Ground living area')
plt.ylabel('Sale price (k$)')
plt.yticks([0,200,400,600])
plt.xticks([0,1000,2000,3000,4000,5000])
plt.show()

# %%
plt.hexbin(x=df.GrLivArea, y=df.SalePrice, cmap="BuPu")
plt.title("HexBin", size=12)
plt.xlabel('Ground living area')
plt.ylabel('Sale price (k$)')
plt.yticks([0,200,400,600])
plt.xticks([0,1000,2000,3000,4000,5000])
plt.show()

# %% [markdown]
# ##EVOLUTION OF THE BITCOIN PRICE

# %%
df=pd.read_csv("https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/3_TwoNumOrdered.csv",delimiter=' ')
df
# Out:
#             date    value
# 0     2013-04-28   135.98
# 1     2013-04-29   147.49
# 2     2013-04-30   146.93
# 3     2013-05-01   139.89
# 4     2013-05-02   125.60
# ...          ...      ...
# 1817  2018-04-19  8298.69
# 1818  2018-04-20  8880.23
# 1819  2018-04-21  8997.57
# 1820  2018-04-22  9001.64
# 1821  2018-04-23  8958.55
#
# [1822 rows x 2 columns]

# %% [markdown]
# ###line plot

# %%
df["date"] = pd.to_datetime(df["date"])
plt.plot(df['date'],df.value,color="#69b3a2")
plt.title("Evolution of Bitcoin price", size=12)
plt.xlabel('date')
plt.ylabel('Bitcoin price ($)')
plt.show()

# %% [markdown]
# ###area chart

# %%
df["date"] = pd.to_datetime(df["date"])
plt.plot(df['date'],df.value,color="#69b3a2")
plt.fill_between(df['date'],df.value,color="#69b3a2",alpha=0.5)
plt.title("Evolution of Bitcoin price", size=12)
plt.xlabel('date')
plt.ylabel('Bitcoin price ($)')
plt.show()

# %% [markdown]
# ###connected scatter

# %%
import datetime

# %%
df["date"] = pd.to_datetime(df["date"])
plt.plot(df['date'],df.value,color="#69b3a2",linestyle='-', marker='o')
plt.fill_between(df['date'],df.value,color="#69b3a2",alpha=0.5)
plt.xlim([datetime.date(2018, 4, 14), datetime.date(2018, 4, 24)])
plt.ylim([0, 10000])
plt.title("Evolution of Bitcoin price", size=12)
plt.yticks([0,2500,5000,7500])
plt.xticks([datetime.date(2018, 4, 15),datetime.date(2018, 4, 17),datetime.date(2018, 4, 19),datetime.date(2018, 4, 21),datetime.date(2018, 4, 23)])
plt.xlabel('date')
plt.ylabel('Bitcoin price ($)')
plt.show()

# %% [markdown]
# ###cutting

# %%
df["date"] = pd.to_datetime(df["date"])
plt.plot(df['date'],df.value,color="#69b3a2",linestyle='-', marker='o')
plt.fill_between(df['date'],df.value,color="#69b3a2",alpha=0.5)
plt.xlim([datetime.date(2018, 4, 14), datetime.date(2018, 4, 24)])
plt.ylim([8000, 9100])
plt.title("Evolution of Bitcoin price", size=12)
plt.yticks([8000,8250,8500,8750,9000])
plt.xticks([datetime.date(2018, 4, 15),datetime.date(2018, 4, 17),datetime.date(2018, 4, 19),datetime.date(2018, 4, 21),datetime.date(2018, 4, 23)])
plt.xlabel('date')
plt.ylabel('Bitcoin price ($)')
plt.show()

# %% [markdown]
# ###comparing to a limit

# %%
df["date"] = pd.to_datetime(df["date"])
plt.plot(df['date'],df.value,color="#69b3a2")
plt.fill_between(df['date'],df.value,where=(df.value <= 7500), interpolate=True,color="#69b3a2",alpha=0.5)
plt.xlim([datetime.date(2017, 6, 29), datetime.date(2018, 4, 12)])
plt.title("Evolution of Bitcoin price", size=12)
plt.xlabel('date')
plt.ylabel('Bitcoin price ($)')
plt.show()

# %% [markdown]
# ##EVOLUTION OF BABY NAMES IN THE US

# %%
pip install pyreadr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pyreadr

df = pyreadr.read_r('/content/drive/MyDrive/DV LAB/babynames.rda')

# %%
df=df['babynames']

# %%
df
# Out:
#            year sex       name     n      prop
# 0        1880.0   F       Mary  7065  0.072384
# 1        1880.0   F       Anna  2604  0.026679
# 2        1880.0   F       Emma  2003  0.020521
# 3        1880.0   F  Elizabeth  1939  0.019866
# 4        1880.0   F     Minnie  1746  0.017888
# ...         ...  ..        ...   ...       ...
# 1924660  2017.0   M      Zykai     5  0.000003
# 1924661  2017.0   M     Zykeem     5  0.000003
# 1924662  2017.0   M      Zylin     5  0.000003
# 1924663  2017.0   M      Zylis     5  0.000003
# 1924664  2017.0   M      Zyrie     5  0.000003
#
# [1924665 rows x 5 columns]

# %%
names=["Ashley", "Amanda", "Jessica","Patricia", "Linda", "Deborah",   "Dorothy", "Betty", "Helen"]

# %%
df1 = pd.DataFrame()

# %%
df
# Out:
#            year sex       name     n      prop
# 0        1880.0   F       Mary  7065  0.072384
# 1        1880.0   F       Anna  2604  0.026679
# 2        1880.0   F       Emma  2003  0.020521
# 3        1880.0   F  Elizabeth  1939  0.019866
# 4        1880.0   F     Minnie  1746  0.017888
# ...         ...  ..        ...   ...       ...
# 1924660  2017.0   M      Zykai     5  0.000003
# 1924661  2017.0   M     Zykeem     5  0.000003
# 1924662  2017.0   M      Zylin     5  0.000003
# 1924663  2017.0   M      Zylis     5  0.000003
# 1924664  2017.0   M      Zyrie     5  0.000003
#
# [1924665 rows x 5 columns]

# %%
for i in range(0,len(df)):
  if(df.name[i] in names and df.sex[i]!='M'):
    df1=df1.append(df.loc[i],ignore_index=True)
    # print(i)
    # print(df.loc[i])

# %%
df1
# Out:
#         year sex      name      n      prop
# 0     1880.0   F     Helen  636.0  0.006516
# 1     1880.0   F    Amanda  241.0  0.002469
# 2     1880.0   F     Betty  117.0  0.001199
# 3     1880.0   F   Dorothy  112.0  0.001147
# 4     1880.0   F     Linda   27.0  0.000277
# ...      ...  ..       ...    ...       ...
# 1174  2017.0   F   Dorothy  498.0  0.000266
# 1175  2017.0   F     Linda  404.0  0.000215
# 1176  2017.0   F   Deborah  353.0  0.000188
# 1177  2017.0   F  Patricia  302.0  0.000161
# 1178  2017.0   F     Betty  175.0  0.000093
#
# [1179 rows x 5 columns]

# %%
df1.columns
# Out:
# Index(['year', 'sex', 'name', 'n', 'prop'], dtype='object')

# %%
df1=df1.drop(columns=['sex', 'prop'])

# %%
df1
# Out:
#         year      name      n
# 0     1880.0     Helen  636.0
# 1     1880.0    Amanda  241.0
# 2     1880.0     Betty  117.0
# 3     1880.0   Dorothy  112.0
# 4     1880.0     Linda   27.0
# ...      ...       ...    ...
# 1174  2017.0   Dorothy  498.0
# 1175  2017.0     Linda  404.0
# 1176  2017.0   Deborah  353.0
# 1177  2017.0  Patricia  302.0
# 1178  2017.0     Betty  175.0
#
# [1179 rows x 3 columns]

# %% [markdown]
# ###line plot

# %%
sns.lineplot(data = df1, x = "year", y = "n", hue = "name")
plt.title("Poplarity of American names in the previous 30 years", size=12)
# Out:
# Text(0.5, 1.0, 'Poplarity of American names in the previous 30 years')

# %% [markdown]
# ###area plot

# %%
g = sns.FacetGrid(df1, col='name', hue='name', col_wrap=4, )
g = g.map(plt.plot, 'year', 'n')
g = g.map(plt.fill_between, 'year', 'n', alpha=0.2).set_titles("{col_name} name")
g = g.set_titles("{col_name}")
plt.subplots_adjust(top=0.92)
g = g.fig.suptitle('Poplarity of American names in the previous 30 years')
plt.show()

# %% [markdown]
# ###stacked area chart

# %%
df2=df1.pivot(index='year', columns='name', values='n')
df2
# Out:
# name    Amanda  Ashley  Betty  Deborah  Dorothy  Helen  Jessica  Linda  \
# year
# 1880.0   241.0     NaN  117.0     12.0    112.0  636.0      7.0   27.0
# 1881.0   263.0     NaN  112.0     14.0    109.0  612.0      7.0   38.0
# 1882.0   288.0     NaN  123.0     15.0    115.0  838.0      8.0   36.0
# 1883.0   287.0     NaN  120.0     16.0    141.0  862.0      6.0   49.0
# 1884.0   337.0     NaN  144.0     13.0    163.0  986.0     14.0   33.0
# ...        ...     ...    ...      ...      ...    ...      ...    ...
# 2013.0  1067.0  3937.0  175.0    330.0    335.0  739.0   1947.0  443.0
# 2014.0  1051.0  3554.0  193.0    372.0    384.0  802.0   1796.0  470.0
# 2015.0  1022.0  3423.0  191.0    348.0    397.0  765.0   1585.0  425.0
# 2016.0   996.0  3036.0  177.0    349.0    452.0  815.0   1379.0  436.0
# 2017.0   954.0  2517.0  175.0    353.0    498.0  758.0   1271.0  404.0
#
# name    Patricia
# year
# 1880.0       NaN
# 1881.0       NaN
# 1882.0       NaN
# 1883.0       NaN
# ...

# %%
df2.plot.area()

# %%
data_perc = df2.divide(df2.sum(axis=1), axis=0)

# %%
data_perc.plot.area()

# %% [markdown]
# ###steamplot

# %%
# fig, ax = plt.subplots(figsize=(10,5))
plt.xlim=([1880,2020])

plt.stackplot(df2.index, df2.T, baseline='wiggle', labels=df2.columns)
plt.show()

# %% [markdown]
# ##ELEVEN FEATURES FOR 32 CARS

# %%
df = pd.read_csv('https://gist.githubusercontent.com/ZeccaLehn/4e06d2575eb9589dbe8c365d61cb056c/raw/64f1660f38ef523b2a1a13be77b002b98665cdfe/mtcars.csv')
df
df=df.drop(columns=['vs','am','gear','carb'])

# %%
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60
# ...

# %% [markdown]
# ###histogram

# %%
fig, axs = plt.subplots(2, 3, figsize=(10, 10))

sns.histplot(data=df, x="disp", kde=False, color="teal", ax=axs[0, 0])
sns.histplot(data=df, x="drat",  kde=False, color="teal", ax=axs[0, 1])
sns.histplot(data=df, x="hp",  kde=False, color="teal", ax=axs[0, 2])
sns.histplot(data=df, x="mpg",  kde=False, color="teal", ax=axs[1, 0])
sns.histplot(data=df, x="qsec",  kde=False, color="teal", ax=axs[1, 1])
sns.histplot(data=df, x="wt",  kde=False, color="teal", ax=axs[1, 2])

# %%
sns.pairplot(df,diag_kind="kde")
plt.show()

# %% [markdown]
# ###dendrogram

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec'], dtype='object')

# %%
df = df.set_index('Unnamed: 0')

# %%
df
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec
# Unnamed: 0
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00
# ...

# %%
from scipy.cluster import hierarchy

# %%
Z = hierarchy.linkage(df, 'ward')

# %%
hierarchy.dendrogram(Z, orientation="left", labels=df.index)
plt.show()

# %% [markdown]
# ###heatmap

# %%
sns.heatmap(df)

# %%
sns.clustermap(df, metric="correlation", method="single", cmap="Blues", standard_scale=1)

# %% [markdown]
# #Categoric

# %% [markdown]
# ##WHO SELLS MORE WEAPONS?

# %%
df=pd.read_csv("https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/7_OneCatOneNum.csv")
df=df.dropna()

# %% [markdown]
# ###lollipop

# %%
ordered_df = df.sort_values(by='Value')
my_range=range(1,len(df.index)+1)
df
# Out:
#                 Country    Value
# 0         United States  12394.0
# 1                Russia   6148.0
# 2         Germany (FRG)   1653.0
# 3                France   2162.0
# 4        United Kingdom   1214.0
# 5                 China   1131.0
# 7           Netherlands   1167.0
# 8                 Italy    660.0
# 9                Israel   1263.0
# 10              Ukraine    240.0
# 11                Spain    814.0
# 12               Sweden     83.0
# 13          Switzerland    186.0
# 14               Canada     87.0
# 15          South Korea    587.0
# 16              Belarus     23.0
# 17               Norway    134.0
# 18               Turkey    244.0
# 19         South Africa     74.0
# 20       Czech Republic    110.0
# 21               Poland      3.0
# 22              Belgium     12.0
# 23            Australia     97.0
# 24               Brazil     45.0
# 27              Finland     58.0
# 29                Japan      2.0
# 30             Slovakia     22.0
# ...

# %%
plt.hlines(y=my_range, xmin=0, xmax=ordered_df['Value'], color='skyblue')
plt.plot(ordered_df['Value'], my_range, "o")
plt.yticks(my_range, ordered_df['Country'])
plt.xlabel('Value')
plt.show()

# %% [markdown]
# ###barplot

# %%
plt.barh(y=df.Country, width=df.Value);

# %% [markdown]
# ###circular bar plot

# %%
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')
upperLimit = 10000
lowerLimit = 3000
labelPadding = 4

max = df['Value'].max()
slope = (max - lowerLimit) / max
heights = slope * df.Value 
width = 2*np.pi / len(df.index)

indexes = list(range(1, len(df.index)+1))
angles = [element * width for element in indexes]
angles

bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

for bar, angle, height, label in zip(bars,angles, heights, df["Country"]):

    rotation = np.rad2deg(angle)

    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor")

# %% [markdown]
# ###treemap

# %%
pip install squarify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import squarify

# %%
plt.figure(figsize=(20,10))
squarify.plot(sizes=df['Value'], label=df['Country'], alpha=.8 )
plt.axis('off')
plt.show()

# %% [markdown]
# ###circle packing

# %%
pip install circlify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import circlify

# %%
circles = circlify.circlify(
    df['Value'].tolist(), 
    show_enclosure=False, 
    target_enclosure=circlify.Circle(x=0, y=0, r=1))

# %%
print(circles)
# Out:
# [Circle(x=0.017486848887727394, y=0.32395940332227563, r=0.007004249884142104, level=1, ex={'datum': 2.0}), Circle(x=-0.1027890175558955, y=0.47932444291760357, r=0.007004249884142104, level=1, ex={'datum': 2.0}), Circle(x=-0.032101024339555834, y=0.4248802022486228, r=0.008578419123548172, level=1, ex={'datum': 3.0}), Circle(x=-0.08315305190639843, y=0.4749930945055071, r=0.013103751658905413, level=1, ex={'datum': 7.0}), Circle(x=0.030584010506331034, y=0.30004223302716787, r=0.01566197887233677, level=1, ex={'datum': 10.0}), Circle(x=-0.31587389459675824, y=0.49467033230785695, r=0.017156838247096344, level=1, ex={'datum': 12.0}), Circle(x=-0.11437496412449116, y=0.042670431354763186, r=0.017156838247096344, level=1, ex={'datum': 12.0}), Circle(x=-0.4056873326638772, y=0.4346985894574299, r=0.023230468803589636, level=1, ex={'datum': 22.0}), Circle(x=-0.4326221181216397, y=0.3968418059743802, r=0.023230468803589636, level=1, ex={'datum': 22.0}), Circle(x=-0.048450839863864247, y=0
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10))

# Remove axes
ax.axis('off')

# Find axis boundaries
lim = max(
    max(
        abs(circle.x) + circle.r,
        abs(circle.y) + circle.r,
    )
    for circle in circles
)
plt.xlim(-lim, lim)
plt.ylim(-lim, lim)

# print circles
for circle in circles:
    x, y, r = circle
    ax.add_patch(plt.Circle((x, y), r, alpha=0.2, linewidth=2, fill=False))

for circle in circles:
    if circle.level != 2:
      continue
    x, y, r = circle
    ax.add_patch( plt.Circle((x, y), r, alpha=0.5, linewidth=2, color="lightblue"))

# Print circle and labels for the highest level:
for circle in circles:
    if circle.level != 3:
      continue
    x, y, r = circle
    label = circle.ex["Country"]
    ax.add_patch( plt.Circle((x, y), r, alpha=0.5, linewidth=2, color="#69b3a2"))
    plt.annotate(label, (x,y ), ha='center', color="white")

# Print labels for the continents
for circle in circles:
    if circle.level != 2:
      continue
    x, y, r = circle
    label = circle.ex["Country"]
    plt.annotate(label, (x,y ) ,va='center', ha='center', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round', pad=.5))
